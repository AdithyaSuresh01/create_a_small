# %% [markdown]
# # BookCatalog Exploration
#
# This notebook demonstrates basic usage of the `book_catalog` package.

# %%
from book_catalog.operations import load_catalog, list_books, search_books

books = load_catalog('data/sample_books.json')
list_books(books)[:3]  # show first 3 books

# %%
search_books(books, 'Python')
